# %% [markdown]
# Lab1 Math

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
100 * 234
# Out:
# 23400

# %%
1    + 1
# Out:
# 2

# %%
15%2
# Out:
# 1

# %%
15%2
# Out:
# 1

# %%
0 ==1
# Out:
# False

# %%
15%2==0
# Out:
# False

# %%
15%2==1
# Out:
# True

# %%
if 15%2==1:
    print("odd")
# Out:
# odd
